# %%
import chromadb
from chromadb.utils import embedding_functions
import json

# %% [markdown]
# Similarity search

# %%
save_dir = "f:/General_Directory_VScode/Mini_RAG_assistant/save_data/chunks_with_metadata.json"


with open(save_dir, 'r', encoding='utf-8') as f:
    data = json.load(f)
    chunks = data['chunks']
    metadata = data['metadata']

# %%
client = chromadb.PersistentClient(path="./chroma_db")
 
collection = client.get_or_create_collection(
    name="my_docs",
    embedding_function = embedding_functions.SentenceTransformerEmbeddingFunction(
    model_name="all-MiniLM-L6-v2"
)
)

# %%
query = "what is python?" 
results = collection.query(
    query_texts=[query],
    n_results=5
)

# %%
for i, (doc, meta, dist) in enumerate(zip(
    results['documents'][0],
    results['metadatas'][0],
    results['distances'][0]
)):
    print(f"{i+1}. Source: {meta['source']}, page. {meta['page']}")
    print(f"   Similarity: {1 - dist:.3f}") 
    print(f"   {doc[:200]}...\n")
# Out:
# 1. Source: Practical Python Programming.pdf, page. 19
#    Similarity: 0.696
#    How can it be used?
# • Scripting
# – ‘gluing’ together commands for other software applications
# • Programming
# – text processing, web site development, email, scientific computing
# www.devsource.com/c/a/La...
#
# 2. Source: Practical Python Programming.pdf, page. 8
#    Similarity: 0.690
#    Who is responsible for Python?
# • Created by Guido van Rossum
# – born 31 Jan 1956 (Netherlands)
# – currently works at Google (since 2005)
# • Actively maintained by worldwide users (including van Rossum)
# ...
#
# 3. Source: 20250622115953Python_Datascience.pdf, page. 14
#    Similarity: 0.676
#    al and numerical tools. Most of these folks don’t want
# to learn Python per se, but want to learn the language with the aim of using it as a
# tool for data-intensive and computational science. While a l...
#
# 4. Source: 20250622115953Python_Datascience.pdf, page. 15
#    Similarity: 0.654
#    The usefulness of Python for data science stems primarily from the large and active
# ecosystem of third-party packages: NumPy for manipulation of homogeneous array-
# based data, Pandas for manipulation ...
#
# 5. Source: Practical Python Programming.pdf, page. 74
#    Similarity: 0.653
#    So, are you now a
# fledgling
# pythoneer?
# OR
# Do you feel like
# you’ve found the
# ‘holy grail’ of
# programming
# languages?
# ...

# %% [markdown]
# Hybrid search

# %%
client = chromadb.PersistentClient(path="./chroma_db")

collection = client.get_or_create_collection(
    name="my_docs",
    embedding_function=embedding_functions.SentenceTransformerEmbeddingFunction(
        model_name="all-MiniLM-L6-v2"
    )
)

# %%
 
results = collection.query(
    query_texts=["how create model llm?"],
    n_results=5, 
)

# %%
for doc, meta in zip(results['documents'][0], results['metadatas'][0]):
    print(f"{meta['source']}: {doc[:100]}...")
# Out:
# llm-datasette-io-en-latest.pdf: LLM documentation, Release 0.32a3-5-gaf977da
# (continued from previous page)
# --id-gte TEXT
# Return res...
# llm-datasette-io-en-latest.pdf: LLM documentation, Release 0.32a3-5-gaf977da
# llm models
# Or add --options to include details of the o...
# llm-datasette-io-en-latest.pdf: LLM documentation, Release 0.32a3-5-gaf977da
# • Add -h for --help for all llm CLI commands. #1134
# • A...
# llm-datasette-io-en-latest.pdf: , --model TEXT
# Specific model IDs
# -h, --help
# Show this message and exit.
# llm models default –help
# Us...
# llm-datasette-io-en-latest.pdf: LLM documentation, Release 0.32a3-5-gaf977da
# llm models options set –help
# Usage: llm models options ...
